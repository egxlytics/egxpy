# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt
from datetime import timedelta
import matplotlib.pyplot as plt
import seaborn as sns
from egxpy.download import  get_OHLCV_data,get_EGX_intraday_data, get_EGXdata
import warnings
warnings.filterwarnings("ignore")
plt.rcParams['figure.figsize'] = [20, 10]
plt.style.use('ggplot')

# %%
date = dt.today().date()
end = date
start = dt(2020, 5, 17).date()
daily_prices = get_EGXdata(stock_list=['ABUK','COMI','TMGH','FWRY', 'SWDY', 'TALM'],interval='Daily',start=start,end=end)
daily_prices    #daily close prices
# Out:
# you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
#              ABUK       COMI   TMGH       FWRY   SWDY   TALM
# Date
# 2020-05-17  11.93  32.175385   5.08   2.397528   7.51    NaN
# 2020-05-18  11.75  32.085648   5.00   2.381650   7.21    NaN
# 2020-05-19  11.87  32.379782   5.03   2.442892   7.28    NaN
# 2020-05-20  11.73  32.030809   5.01   2.565377   7.24    NaN
# 2020-05-21  11.96  31.163359   5.05   2.608474   7.43    NaN
# ...           ...        ...    ...        ...    ...    ...
# 2025-04-27  53.23  79.920000  50.51  10.200000  83.01  10.99
# 2025-04-28  52.91  80.500000  50.23  10.350000  81.92  10.90
# 2025-04-29  54.00  79.960000  51.65  10.660000  82.00  10.97
# 2025-04-30  53.97  80.970000  51.93  10.660000  82.00  10.97
# 2025-05-04  54.99  80.700000  52.78  10.660000  82.11  11.00
#
# [1201 rows x 6 columns]

# %%
ohlcv = get_OHLCV_data(symbol='EGX30',exchange='EGX',interval='Daily',n_bars=100)
ohlcv
# Out:
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
#                         symbol     open     high      low    close  \
# datetime
# 2024-12-02 10:00:00  EGX:EGX30  30502.3  30675.4  30429.5  30525.3
# 2024-12-03 10:00:00  EGX:EGX30  30532.5  30642.5  30525.3  30628.7
# 2024-12-04 10:00:00  EGX:EGX30  30636.0  31005.2  30628.7  30832.6
# 2024-12-05 10:00:00  EGX:EGX30  30857.0  31035.9  30824.1  30839.6
# 2024-12-08 10:00:00  EGX:EGX30  30878.3  31233.0  30839.6  31060.5
# ...                        ...      ...      ...      ...      ...
# 2025-04-27 10:00:00  EGX:EGX30  31620.6  31885.2  31592.5  31855.1
# 2025-04-28 10:00:00  EGX:EGX30  31870.0  32048.7  31768.2  32015.0
# 2025-04-29 10:00:00  EGX:EGX30  32082.7  32218.7  32015.0  32043.5
# 2025-04-30 10:00:00  EGX:EGX30  32050.5  32138.0  31962.8  32126.2
# 2025-05-04 10:00:00  EGX:EGX30  32127.0  32432.7  32126.2  32351.7
#
#                           volume
# datetime
# 2024-12-02 10:00:00  147138000.0
# 2024-12-03 10:00:00  101683000.0
# 2024-12-04 10:00:00  123614000.0
# 2024-12-05 10:00:00  112516000.0
# 2024-12-08 10:00:00  120188000.0
# ...                          ...
# 2025-04-27 10:00:00  232393000.0
# 2025-04-28 10:00:00  179465000.0
# 2025-04-29 10:00:00  144398000.0
# 2025-04-30 10:00:00  143744000.0
# 2025-05-04 10:00:00  187146000.0
#
# [100 rows x 6 columns]

# %%
start = end - timedelta(days=10) # last 10 days
intrday_prices = get_EGX_intraday_data(stock_list=['ABUK', 'COMI'], interval='5 Minute', start=start,end=end)
intrday_prices
# Out:
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# ERROR:tvDatafeed.main:Connection to remote host was lost.
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# WARNING:retry.api:'NoneType' object is not subscriptable, retrying in 0.5 seconds...
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
#                             ABUK   COMI
# datetime
# 2025-04-27 11:00:00+02:00  53.20  79.51
# 2025-04-27 11:05:00+02:00  53.40  79.55
# 2025-04-27 11:10:00+02:00  53.21  79.50
# 2025-04-27 11:15:00+02:00  53.35  79.52
# 2025-04-27 11:20:00+02:00  53.04  79.70
# ...                          ...    ...
# 2025-04-30 14:55:00+02:00  53.83  80.77
# 2025-04-30 15:00:00+02:00  53.77  80.90
# 2025-04-30 15:05:00+02:00  53.63  80.90
# 2025-04-30 15:10:00+02:00  53.63  80.70
# 2025-04-30 15:25:00+02:00  53.97  80.97
#
# [208 rows x 2 columns]

# %%
plt.figure(figsize=(20,10))

sns.lineplot(daily_prices,dashes=False)
plt.show()
